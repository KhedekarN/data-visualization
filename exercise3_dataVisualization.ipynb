# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cancer_df=pd.read_csv(r'C:\Users\nikit\Desktop\Ex_Files_Python_Data_Visualization\Exercise_Files\4 Matplotlib\data\wisconsinBreastCancer.csv')

# %%
cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_df['diagnosis'].value_counts(dropna=False)
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
malignant= cancer_df.loc[cancer_df["diagnosis"]=='M','area_mean'].values
belign= cancer_df.loc[cancer_df["diagnosis"]=='B','area_mean'].values

plt.boxplot([malignant,belign],labels=['M','B'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2154d4b3dd8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2154d4cb780>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2154d4b3c88>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2154d4cbe10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2154d4cbef0>,
# ...
#  'means': []}

# %% [markdown]
# ## box plot using pandas

# %%
cancer_df.boxplot(column='area_mean',by ='diagnosis')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x='diagnosis', y='area_mean',data=cancer_df)
